# %%
from Utils import get_paths,get_inter_pos_frames
import sklearn
import numpy as np
import copy
file_name = get_paths('Data/')[:2]

# %%
slice1,slice2 = get_inter_pos_frames(file_name[0],file_name[1])

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.rcParams["font.family"] = "Times New Roman"
slice1.keys()
fig,ax = plt.subplots(1,2,dpi=200,figsize=(8,4))
for line in slice1['Position']:
    sns.scatterplot(x=line[:,0],y=line[:,1],s=5,ax=ax[0])
for line in slice2['Position']:
    sns.scatterplot(x=line[:,0],y=line[:,1],s=5,ax=ax[1])

# %%
len(slice1['Position']),len(slice2['Position'])
slice1_pos = slice1['Position']
slice2_pos = slice2['Position']
scale_max=[min(np.max(slice1['Position'][i][:,0]),np.max(slice2['Position'][i][:,0])) for i in range(len(slice1['Position']))]
scale_min=[max(np.min(slice1['Position'][i][:,0]),np.min(slice2['Position'][i][:,0])) for i in range(len(slice1['Position']))]
scale = list(zip(scale_min,scale_max))
scale
# Out:
# [(152.56131394618006, 487.1090882230344),
#  (155.58384292751322, 490.13161720436756),
#  (158.65137531411838, 486.98867966343226),
#  (155.46343436791108, 490.0565262381805),
#  (146.11034108757838, 486.8685852919732),
#  (142.9674035466431, 489.9361176785784),
#  (139.82478019385087, 486.7931801376431),
#  (136.68184265291558, 489.8157091189762),
#  (133.53921930012336, 486.673085766184),
#  (111.76550035285284, 489.69561474751714),
#  (127.20865500112382, 486.55267720658185),
#  (105.47962527098228, 489.57520618791494),
#  (102.33700191819004, 486.43258283512273),
#  (105.35953089952318, 489.50011522172787),
#  (96.95641325070916, 486.3121742755206),
#  (100.04285356666237, 489.3797066621257),
#  (96.9187104438457, 486.2370833093335),
#  (99.96014653198172, 489.25961229066667),
#  (96.83616050419367, 486.1166747497314),
#  (99.92260082014685, 489.13920373106447),
#  (96.75345346951305, 485.99658037827226),
#  (99.83989378546623, 489.0641127648774),
#  (96.7157506626496, 485.8761718186702),
#  (99.7571867507856, 471.5333424677641),
#  (96.63320072299756, 468.409356439976),
#  (99.67463681113358, 465.2402090893423),
#  (101.5400879706762, 467.0945801036747),
#  (99.63693400427012, 465.2025062824788),
#  (96.51294797648205, 462.0785202546908),
#  (99.55438406461809, 465.11995634282675),
#  (96.43024094180143, 461.99581322001006),
#  (99.47167702993745, 463.7114538198212),
#  (96.3476910021494, 466.77898620642634),
#  (99.4341313181026, 469.80151518775943),
#  (96.26498396746878, 466.6585776468242),
#  (99.35142428342195, 469.68110662815735),
#  (96.22728116060532, 467.9584326497667),
#  (99.26887434376994, 464.8344466219786),
#  (96.14473122095329, 461.71030349916197),
#  (99.1861673090893, 464.7967438151152),
#  (96.06202418627265, 467.83817990325116),
#  (99.14846450222585, 464.71403678043447),
#  (102.18990059036189, 467.7554728685705),
#  (99.06591456257381, 464.63148684078243),
#  (102.15235487852702, 467.71792715673564),
#  (105.19379096666304, 464.5487798061019),
#  (108.28023128261623, 461.4247937783138),
#  (117.53209371449351, 464.511234094267),
#  (120.57368689765815, 461.3420867436331),
#  (123.66012721361133, 458.2181007158451),
#  (126.70156330174736, 461.30454103179824),
#  (129.78800361770055, 458.1803979089816),
#  (132.82943970583656, 461.22183399711764),
#  (135.9158800217898, 458.09769087430107),
#  (138.95731610992578, 461.13928405746566),
#  (142.04375642587902, 462.4031322611268),
#  (151.29561885775627, 459.2605089083345),
#  (148.17163282996822, 457.9324338999683),
#  (151.21306891810426, 461.0188742159215),
#  (148.0889257952876, 462.16262933006556),
#  (157.34094532219345, 459.01969178913026),
#  (160.4273856381467, 457.81218115345285),
#  (163.46882172628267, 458.9446008229432),
#  (172.72068415815997, 461.9671298042763),
#  (175.80712447411315, 460.816071529754),
#  (178.84856056224922, 461.84672124467414),
#  (181.93500087820237, 458.70409789188193),
#  (191.18702040510829, 461.726626873215),
#  (188.06287728229162, 458.5836893322798),
#  (184.8938870266864, 457.5266714326047),
#  (187.98032734263955, 435.8160964113529),
#  (197.23218977451688, 432.6919532885362),
#  (206.48420930142274, 429.56781016571955),
#  (228.1572386108397, 420.2332406991616),
#  (274.5822790296446, 410.8986712326037),
#  (283.83429855655044, 401.56410176604584),
#  (305.50717077093884, 379.853526744794),
#  (345.72178484600244, 364.3083738394662)]

# %%
slice1_pos = copy.deepcopy(slice1['Position'])
slice2_pos = copy.deepcopy(slice2['Position'])
values = [slice1_pos[0][i] for i in range(len(slice1_pos[0])) if scale[0][0]<= slice1_pos[0][i][0] <= scale[0][1]]
cutted_pos = []
for n in range(len(slice1_pos)):
    cutted_pos.append(np.array([slice1_pos[n][i] for i in range(len(slice1_pos[n])) if scale[n][0]<= slice1_pos[n][i][0] <= scale[n][1]]))

# %%
for line in cutted_pos:
    sns.scatterplot(x=line[:,0],y=line[:,1],s=5)

# %%
sns.scatterplot(cutted_pos)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[89], line 1
# ----> 1 sns.scatterplot(cutted_pos)
#
# File ~/anaconda3/envs/torch/lib/python3.11/site-packages/seaborn/relational.py:603, in scatterplot(data, x, y, hue, size, style, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, style_order, legend, ax, **kwargs)
#     594 def scatterplot(
#     595     data=None, *,
#     596     x=None, y=None, hue=None, size=None, style=None,
#    (...)
#     600     **kwargs
#     601 ):
# --> 603     p = _ScatterPlotter(
#     604         data=data,
#     605         variables=dict(x=x, y=y, hue=hue, size=size, style=style),
#     606         legend=legend
#     607     )
#     609     p.map_hue(palette=palette, order=hue_order, norm=hue_norm)
#     610     p.map_size(sizes=sizes, order=size_order, norm=size_norm)
#
# File ~/anaconda3/envs/torch/lib/python3.11/site-packages/seaborn/relational.py:390, in _ScatterPlotter.__init__(self, data, variables, legend)
#     381 def __init__(self, *, data=None, variables={}, legend=None):
#     382
#     383     # TODO this is messy, we want the mapping to be agnostic about
#     384     # the kind of plot to draw, but for the time being we need to set
#     385     # this information so the SizeMapping can use it
#     386     self._default_size_range = (
#     387         np.r_[.5, 2] * np.square(mpl.rcParams["lines.markersize"])
#     388     )
# --> 390     super().__init__(data=data, variables=variables)
#     392     self.legend = legend
#
# File ~/anaconda3/envs/torch/lib/python3.11/site-packages/seaborn/_base.py:634, in VectorPlotter.__init__(self, data, variables)
#     629 # var_ordered is relevant only for categorical axis variables, and may
#     630 # be better handled by an internal axis information object that tracks
#     631 # such information and is set up by the scale_* methods. The analogous
#     632 # information for numeric axes would be information about log scales.
#     633 self._var_ordered = {"x": False, "y": False}  # alt., used DefaultDict
# --> 634 self.assign_variables(data, variables)
#     636 # TODO Lots of tests assume that these are called to initialize the
#     637 # mappings to default values on class initialization. I'd prefer to
#     638 # move away from that and only have a mapping when explicitly called.
#     639 for var in ["hue", "size", "style"]:
#
# File ~/anaconda3/envs/torch/lib/python3.11/site-packages/seaborn/_base.py:673, in VectorPlotter.assign_variables(self, data, variables)
#     671 if x is None and y is None:
#     672     self.input_format = "wide"
# --> 673     frame, names = self._assign_variables_wideform(data, **variables)
#     674 else:
#     675     # When dealing with long-form input, use the newer PlotData
#     676     # object (internal but introduced for the objects interface)
#     677     # to centralize / standardize data consumption logic.
#     678     self.input_format = "long"
#
# File ~/anaconda3/envs/torch/lib/python3.11/site-packages/seaborn/_base.py:795, in VectorPlotter._assign_variables_wideform(self, data, **kwargs)
#     792 wide_data = pd.DataFrame(data, copy=True)
#     794 # At this point we should reduce the dataframe to numeric cols
# --> 795 numeric_cols = [
#     796     k for k, v in wide_data.items() if variable_type(v) == "numeric"
#     797 ]
#     798 wide_data = wide_data[numeric_cols]
#     800 # Now melt the data to long form
#
# File ~/anaconda3/envs/torch/lib/python3.11/site-packages/seaborn/_base.py:796, in <listcomp>(.0)
#     792 wide_data = pd.DataFrame(data, copy=True)
#     794 # At this point we should reduce the dataframe to numeric cols
#     795 numeric_cols = [
# --> 796     k for k, v in wide_data.items() if variable_type(v) == "numeric"
#     797 ]
#     798 wide_data = wide_data[numeric_cols]
#     800 # Now melt the data to long form
#
# File ~/anaconda3/envs/torch/lib/python3.11/site-packages/seaborn/_base.py:1523, in variable_type(vector, boolean_type)
#    1519 with warnings.catch_warnings():
#    1520     warnings.simplefilter(
#    1521         action='ignore', category=(FutureWarning, DeprecationWarning)
#    1522     )
# -> 1523     if np.isin(vector, [0, 1]).all():
#    1524         return VariableType(boolean_type)
#    1526 # Defer to positive pandas tests
#
# File ~/anaconda3/envs/torch/lib/python3.11/site-packages/numpy/lib/arraysetops.py:890, in isin(element, test_elements, assume_unique, invert, kind)
#     769 """
#     770 Calculates ``element in test_elements``, broadcasting over `element` only.
#     771 Returns a boolean array of the same shape as `element` that is True
#    (...)
#     887        [ True, False]])
#     888 """
#     889 element = np.asarray(element)
# --> 890 return in1d(element, test_elements, assume_unique=assume_unique,
#     891             invert=invert, kind=kind).reshape(element.shape)
#
# File ~/anaconda3/envs/torch/lib/python3.11/site-packages/numpy/lib/arraysetops.py:733, in in1d(ar1, ar2, assume_unique, invert, kind)
#     731         mask = np.zeros(len(ar1), dtype=bool)
#     732         for a in ar2:
# --> 733             mask |= (ar1 == a)
#     734     return mask
#     736 # Otherwise use sorting
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %%
fig,ax = plt.subplots(8,1,dpi=150,figsize=[8,8],sharex=True)
for i in range(len(ax)):
    ax[i].set_xticks([])
    sns.heatmap(slice1['Gene_features'][i+30][:,:80],cmap='Reds',ax=ax[i],vmin=0,vmax=9)
plt.tight_layout()

# %%
sample_size=50
x, y = np.meshgrid(np.linspace(0, 100, 100), np.linspace(0, 100, 100))
# 定义扭曲函数
def nonlinear_transformation(x, y):
    x_new = x ** 2 + y ** 2
    y_new = x * y
    return x_new, y_new

# 对网格进行扭曲
x_new, y_new = nonlinear_transformation(x, y)

# %%
x
# Out:
# array([[  0.        ,   1.01010101,   2.02020202, ...,  97.97979798,
#          98.98989899, 100.        ],
#        [  0.        ,   1.01010101,   2.02020202, ...,  97.97979798,
#          98.98989899, 100.        ],
#        [  0.        ,   1.01010101,   2.02020202, ...,  97.97979798,
#          98.98989899, 100.        ],
#        ...,
#        [  0.        ,   1.01010101,   2.02020202, ...,  97.97979798,
#          98.98989899, 100.        ],
#        [  0.        ,   1.01010101,   2.02020202, ...,  97.97979798,
#          98.98989899, 100.        ],
#        [  0.        ,   1.01010101,   2.02020202, ...,  97.97979798,
#          98.98989899, 100.        ]])

# %%
sns.scatterplot(x=np.squeeze(np.reshape(x,-1)),y=np.squeeze(np.reshape(y,-1)),s=3)
# Out:
# <Axes: >

# %%
sns.scatterplot(x=np.squeeze(np.reshape(x_new,-1)),y=np.squeeze(np.reshape(y_new,-1)),s=3)
# Out:
# <Axes: >

# %%
x, y = np.meshgrid(np.linspace(0, 100, 100), np.linspace(0, 100, 100))
x_ = copy.deepcopy(x)
y_ = copy.deepcopy(y)
x_ += np.random.normal(0, 0.01, size=x.shape)
y_ += np.random.normal(0, 0.01, size=y.shape)
flatten = lambda x:x.reshape(-1)

# %%
fig,ax = plt.subplots(1,2,dpi=300,figsize=[8,4])
sns.scatterplot(x=flatten(x),y=flatten(y),s=3,ax=ax[0])
sns.scatterplot(x=flatten(x_),y=flatten(y_),s=3,ax=ax[1])
plt.tight_layout()
